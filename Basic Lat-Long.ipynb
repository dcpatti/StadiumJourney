# %% [markdown]
# ### Work in Progress
#
# #### Completed so far:
#
# *Import of a handful of schedules
#
# *Basic data cleaning
#
# *Matrix of distances between stadiums
#
#
# #### Up next:
#
# Start building a route map of each team's movements, then use the distance matrix where needed

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import glob
import os
#import geopandas as gpd
from sklearn.neighbors import DistanceMetric #for creating the matrix

#from math import radians
#import contextily as ctx
#import shapely

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import to_hex
import seaborn as sns
# %matplotlib inline
# Out:
# C:\Users\patti\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:30: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# C:\Users\patti\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:167: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# C:\Users\patti\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:284: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_Gram=True, verbose=0,
# C:\Users\patti\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:862: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# C:\Users\patti\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:1101: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# C:\Users\patti\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:1127: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, positive=False):
# C:\Users\patti\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:1362: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# C:\Users\patti\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:1602: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# C:\Users\patti\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:1738: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, positive=False):
# C:\Users\patti\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:29: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   EPS = np.finfo(np.float).eps

# %%
path = r'data' # use your path
all_files = glob.glob(path + "/*.csv")

col_list = ('START DATE', 'START TIME', 'START TIME ET', 'SUBJECT', 'LOCATION')

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0, usecols= col_list)
    df['team_file'] = os.path.basename(filename)
    li.append(df)

mlb_df = pd.concat(li, axis=0, ignore_index=True)

mlb_df.head()
# Out:
#   START DATE START TIME START TIME ET                  SUBJECT  \
# 0  2/26/2022        NaN           NaN  Athletics at White Sox
# 1  2/27/2022    1:05 PM       3:05 PM   Guardians at Athletics
# 2  2/28/2022   12:10 PM       3:10 PM      Athletics at Padres
# 3   3/1/2022    1:05 PM       3:05 PM     Dodgers at Athletics
# 4   3/2/2022    1:05 PM       3:05 PM        Reds at Athletics
#
#                      LOCATION           team_file
# 0  Camelback Ranch - Glendale  Athletics.2022.csv
# 1      Hohokam Stadium - Mesa  Athletics.2022.csv
# 2     Peoria Stadium - Peoria  Athletics.2022.csv
# 3      Hohokam Stadium - Mesa  Athletics.2022.csv
# 4      Hohokam Stadium - Mesa  Athletics.2022.csv

# %%
mlb_df.LOCATION.unique()
# Out:
# array(['Camelback Ranch - Glendale', 'Hohokam Stadium - Mesa',
#        'Peoria Stadium - Peoria', 'Sloan Park - Mesa',
#        'Surprise Stadium - Surprise',
#        'Salt River Fields at Talking Stick - Scottsdale',
#        'Las Vegas Ballpark - Summerlin', 'Goodyear Ballpark - Goodyear',
#        'Scottsdale Stadium - Scottsdale',
#        'American Family Fields of Phoenix - Phoenix',
#        'Tempe Diablo Stadium - Tempe', 'Oracle Park - San Francisco',
#        'Oakland Coliseum - Oakland', 'Citizens Bank Park - Philadelphia',
#        'Tropicana Field - St. Petersburg', 'Rogers Centre - Toronto',
#        'Target Field - Minneapolis', 'Comerica Park - Detroit',
#        'Angel Stadium - Anaheim', 'T-Mobile Park - Seattle',
#        'Truist Park - Atlanta', 'Progressive Field - Cleveland',
#        'Fenway Park - Boston', 'Kauffman Stadium - Kansas City',
#        'Yankee Stadium - Bronx', 'Globe Life Field - Arlington',
#        'Minute Maid Park - Houston', 'Guaranteed Rate Field - Chicago',
#        'Nationals Park - Washington',
#        'Oriole Park at Camden Yards - Baltimore',
#        'Dodger Stadium - Los Angeles', 'Petco Park - San Diego',
#        'Sahlen Field - Buffalo', 'Coors Field - Denver',
#        'Chase Field - Phoenix', 'Roger Dean Chevrolet Stadium - Jupiter',
#        'The Ballpark of the Palm Beaches - West Palm Beach',
#        'Clover Park - Port St. Lucie', 'JetBlue Park - Ft. Myers',
#        'LECOM Park - Bradenton', 'loanDepot park - Miami',
#        'Citi Field - Flushing', 'Busch Stadium - St. Louis',
#        'PNC Park - Pittsburgh', 'Great American Ball Park - Cincinnati',
#        'Wrigley Field - Chicago', 'American Family Field - Milwaukee',
#        'TD Ballpark - Dunedin'], dtype=object)

# %%
mlb_df["lon"] = ""
mlb_df["lat"] = ""

# %%
mlb_df.loc[(mlb_df.LOCATION =='Nationals Park - Washington'), ('lon', 'lat')] = ('-77.007433','38.87301')
mlb_df.loc[(mlb_df.LOCATION =='Dodger Stadium - Los Angeles'), ('lon', 'lat')] = ('-118.239958','34.073851')
mlb_df.loc[(mlb_df.LOCATION =='Busch Stadium - St. Louis'), ('lon', 'lat')] = ('-90.192821','38.622619')
mlb_df.loc[(mlb_df.LOCATION =='Citi Field - Flushing'), ('lon', 'lat')] = ('-73.845821','40.757088')
mlb_df.loc[(mlb_df.LOCATION =='TD Ballpark - Dunedin'), ('lon', 'lat')] = ('-82.7873','28.00041')
mlb_df.loc[(mlb_df.LOCATION =='Yankee Stadium - Bronx'), ('lon', 'lat')] = ('-73.926175','40.829643')
mlb_df.loc[(mlb_df.LOCATION =='Chase Field - Phoenix'), ('lon', 'lat')] = ('-112.066664','33.445526')
mlb_df.loc[(mlb_df.LOCATION =='Wrigley Field - Chicago'), ('lon', 'lat')] = ('-87.6553333','41.948438')
mlb_df.loc[(mlb_df.LOCATION =='Truist Park - Atlanta'), ('lon', 'lat')] = ('-84.467684','33.8907')
mlb_df.loc[(mlb_df.LOCATION =='Citizens Bank Park - Philadelphia'), ('lon', 'lat')] = ('-87.166495','39.906057')
mlb_df.loc[(mlb_df.LOCATION =='Tropicana Field - St. Petersburg'), ('lon', 'lat')] = ('-82.653392','27.768225')
mlb_df.loc[(mlb_df.LOCATION =='loanDepot park - Miami'), ('lon', 'lat')] = ('-80.21957','25.778318')
mlb_df.loc[(mlb_df.LOCATION =='Petco Park - San Diego'), ('lon', 'lat')] = ('-117.156904','47.591391')
mlb_df.loc[(mlb_df.LOCATION =='Oracle Park - San Francisco'), ('lon', 'lat')] = ('-112.332327','37.778595')
mlb_df.loc[(mlb_df.LOCATION =='Oriole Park at Camden Yards - Baltimore'), ('lon', 'lat')] = ('-76.621512','39.284052')
mlb_df.loc[(mlb_df.LOCATION =='American Family Field - Milwaukee'), ('lon', 'lat')] = ('-87.97115','43.027978')
mlb_df.loc[(mlb_df.LOCATION == 'PNC Park - Pittsburgh'), ('lon', 'lat')] = ('-80.005666','40.446855')
mlb_df.loc[(mlb_df.LOCATION == 'Great American Ball Park - Cincinnati'), ('lon', 'lat')] = ('-84.508151','39.097931')
mlb_df.loc[(mlb_df.LOCATION == 'Coors Field - Denver'), ('lon', 'lat')] = ('-104.994178','39.755882')
mlb_df.loc[(mlb_df.LOCATION == 'Fenway Park - Boston'), ('lon', 'lat')] = ('-71.097218','42.346676')
mlb_df.loc[(mlb_df.LOCATION == 'Globe Life Field - Arlington'), ('lon', 'lat')] = ('-97.082504','32.75128')
mlb_df.loc[(mlb_df.LOCATION == 'Oakland Coliseum - Oakland'), ('lon', 'lat')] = ('-122.332327','37.752483')
mlb_df.loc[(mlb_df.LOCATION == 'T-Mobile Park - Seattle'), ('lon', 'lat')] = ('-122.332327','47.591391')
mlb_df.loc[(mlb_df.LOCATION == 'Target Field - Minneapolis'), ('lon', 'lat')] = ('-93.27776','44.981712')
mlb_df.loc[(mlb_df.LOCATION == 'Guaranteed Rate Field - Chicago'), ('lon', 'lat')] = ('-87.633752','41.829902')
mlb_df.loc[(mlb_df.LOCATION == 'Progressive Field - Cleveland'), ('lon', 'lat')] = ('-81.685229','41.496211')


mlb_df.loc[(mlb_df.LOCATION == 'Sahlen Field - Buffalo'), ('lon', 'lat')] = ('-78.8738','42.8804')
mlb_df.loc[(mlb_df.LOCATION == 'Rogers Centre - Toronto'), ('lon', 'lat')] = ('-79.389353','43.641438')

mlb_df.loc[(mlb_df.LOCATION == 'Minute Maid Park - Houston'), ('lon', 'lat')] = ('-95.354538','29.757697')
mlb_df.loc[(mlb_df.LOCATION == 'Angel Stadium - Anaheim'), ('lon', 'lat')] = ('-117.882732','33.800308')
mlb_df.loc[(mlb_df.LOCATION == 'Kauffman Stadium - Kansas City'), ('lon', 'lat')] = ('-94.480314','39.051672')
mlb_df.loc[(mlb_df.LOCATION == 'Comerica Park - Detroit'), ('lon', 'lat')] = ('-83.04852','42.338998')



mlb_df.head()
# Out:
#   START DATE START TIME START TIME ET                  SUBJECT  \
# 0  2/26/2022        NaN           NaN  Athletics at White Sox
# 1  2/27/2022    1:05 PM       3:05 PM   Guardians at Athletics
# 2  2/28/2022   12:10 PM       3:10 PM      Athletics at Padres
# 3   3/1/2022    1:05 PM       3:05 PM     Dodgers at Athletics
# 4   3/2/2022    1:05 PM       3:05 PM        Reds at Athletics
#
#                      LOCATION           team_file lon lat
# 0  Camelback Ranch - Glendale  Athletics.2022.csv
# 1      Hohokam Stadium - Mesa  Athletics.2022.csv
# 2     Peoria Stadium - Peoria  Athletics.2022.csv
# 3      Hohokam Stadium - Mesa  Athletics.2022.csv
# 4      Hohokam Stadium - Mesa  Athletics.2022.csv

# %%
#drop all the Spring Training sites
nan_value = float("NaN")
mlb_df.lon.replace("", nan_value, inplace=True)

mlb_df.dropna(subset = ["lon"], inplace=True)

# %%
#extract team name and year from filename into their own columns

# new data frame with split value columns
new = mlb_df["team_file"].str.split(".", n = 2, expand = True)
  
# making separate first name column from new data frame
mlb_df["ScheduledTeam"]= new[0]
  
# making separate last name column from new data frame
mlb_df["Year"]= new[1]
  
mlb_df.head()
# Out:
#    START DATE START TIME START TIME ET               SUBJECT  \
# 32  3/27/2022        NaN           NaN  Athletics at Giants
# 33  3/28/2022        NaN           NaN  Athletics at Giants
# 34  3/29/2022    6:40 PM       9:40 PM   Giants at Athletics
# 35  3/31/2022    7:07 PM      10:07 PM   Angels at Athletics
# 36   4/1/2022    6:40 PM       9:40 PM   Angels at Athletics
#
#                        LOCATION           team_file          lon        lat  \
# 32  Oracle Park - San Francisco  Athletics.2022.csv  -112.332327  37.778595
# 33  Oracle Park - San Francisco  Athletics.2022.csv  -112.332327  37.778595
# 34   Oakland Coliseum - Oakland  Athletics.2022.csv  -122.332327  37.752483
# 35   Oakland Coliseum - Oakland  Athletics.2022.csv  -122.332327  37.752483
# 36   Oakland Coliseum - Oakland  Athletics.2022.csv  -122.332327  37.752483
#
#    ScheduledTeam  Year
# 32     Athletics  2022
# 33     Athletics  2022
# 34     Athletics  2022
# 35     Athletics  2022
# 36     Athletics  2022

# %%
#extract the Opponent from the SUBJECT column

# new data frame with split value columns
opp = mlb_df["SUBJECT"].str.split(" at", n = 2, expand = True)
  
#columns for visitor and home
mlb_df["Visitor"]= opp[0]
mlb_df["Home"]= opp[1]
  
mlb_df.head()
# Out:
#    START DATE START TIME START TIME ET               SUBJECT  \
# 32  3/27/2022        NaN           NaN  Athletics at Giants
# 33  3/28/2022        NaN           NaN  Athletics at Giants
# 34  3/29/2022    6:40 PM       9:40 PM   Giants at Athletics
# 35  3/31/2022    7:07 PM      10:07 PM   Angels at Athletics
# 36   4/1/2022    6:40 PM       9:40 PM   Angels at Athletics
#
#                        LOCATION           team_file          lon        lat  \
# 32  Oracle Park - San Francisco  Athletics.2022.csv  -112.332327  37.778595
# 33  Oracle Park - San Francisco  Athletics.2022.csv  -112.332327  37.778595
# 34   Oakland Coliseum - Oakland  Athletics.2022.csv  -122.332327  37.752483
# 35   Oakland Coliseum - Oakland  Athletics.2022.csv  -122.332327  37.752483
# 36   Oakland Coliseum - Oakland  Athletics.2022.csv  -122.332327  37.752483
#
#    ScheduledTeam  Year    Visitor        Home
# 32     Athletics  2022  Athletics     Giants
# 33     Athletics  2022  Athletics     Giants
# 34     Athletics  2022     Giants   Athletics
# 35     Athletics  2022     Angels   Athletics
# 36     Athletics  2022     Angels   Athletics

# %%
#clean up any stray scheduling comments

mlb_df.Home.replace("Time", "", inplace=True)
mlb_df.Home.replace("-", "", inplace=True)
mlb_df.Home.replace("TBD", "", inplace=True)

# %%
#prepare matrix of distances between stadiums
#reference https://kanoki.org/2019/12/27/how-to-calculate-distance-in-python-and-pandas-using-scipy-spatial-and-distance-functions/

#first we need to deduplicate the location-lat-lon sets
mlb_deduped =mlb_df.drop_duplicates(subset=['LOCATION', 'lat','lon'], keep='first')
mlb_deduped.head()
# Out:
#    START DATE START TIME START TIME ET                 SUBJECT  \
# 32  3/27/2022        NaN           NaN    Athletics at Giants
# 34  3/29/2022    6:40 PM       9:40 PM     Giants at Athletics
# 42   4/8/2022   12:05 PM       3:05 PM   Athletics at Phillies
# 45  4/11/2022        NaN           NaN      Athletics at Rays
# 49  4/15/2022    4:07 PM       7:07 PM  Athletics at Blue Jays
#
#                              LOCATION           team_file          lon  \
# 32        Oracle Park - San Francisco  Athletics.2022.csv  -112.332327
# 34         Oakland Coliseum - Oakland  Athletics.2022.csv  -122.332327
# 42  Citizens Bank Park - Philadelphia  Athletics.2022.csv   -87.166495
# 45   Tropicana Field - St. Petersburg  Athletics.2022.csv   -82.653392
# 49            Rogers Centre - Toronto  Athletics.2022.csv   -79.389353
#
#           lat ScheduledTeam  Year    Visitor        Home
# 32  37.778595     Athletics  2022  Athletics     Giants
# 34  37.752483     Athletics  2022     Giants   Athletics
# 42  39.906057     Athletics  2022  Athletics    Phillies
# 45  27.768225     Athletics  2022  Athletics       Rays
# 49  43.641438     Athletics  2022  Athletics   Blue Jays

# %%
mlb_deduped['lon'] = pd.to_numeric(mlb_deduped['lon'],errors='coerce')
mlb_deduped['lat'] = pd.to_numeric(mlb_deduped['lat'],errors='coerce')

# %%
#convert lat and lon to radians

mlb_deduped['r_lat'] = np.radians(mlb_deduped['lat'])
mlb_deduped['r_lon'] = np.radians(mlb_deduped['lon'])

mlb_deduped.head()
# Out:
#    START DATE START TIME START TIME ET                 SUBJECT  \
# 32  3/27/2022        NaN           NaN    Athletics at Giants
# 34  3/29/2022    6:40 PM       9:40 PM     Giants at Athletics
# 42   4/8/2022   12:05 PM       3:05 PM   Athletics at Phillies
# 45  4/11/2022        NaN           NaN      Athletics at Rays
# 49  4/15/2022    4:07 PM       7:07 PM  Athletics at Blue Jays
#
#                              LOCATION           team_file         lon  \
# 32        Oracle Park - San Francisco  Athletics.2022.csv -112.332327
# 34         Oakland Coliseum - Oakland  Athletics.2022.csv -122.332327
# 42  Citizens Bank Park - Philadelphia  Athletics.2022.csv  -87.166495
# 45   Tropicana Field - St. Petersburg  Athletics.2022.csv  -82.653392
# 49            Rogers Centre - Toronto  Athletics.2022.csv  -79.389353
#
#           lat ScheduledTeam  Year    Visitor        Home     r_lat     r_lon
# 32  37.778595     Athletics  2022  Athletics     Giants   0.659361 -1.960569
# 34  37.752483     Athletics  2022     Giants   Athletics  0.658905 -2.135102
# 42  39.906057     Athletics  2022  Athletics    Phillies  0.696492 -1.521342
# 45  27.768225     Athletics  2022  Athletics       Rays   0.484647 -1.442574
# 49  43.641438     Athletics  2022  Athletics   Blue Jays  0.761687 -1.385606

# %%
dist = DistanceMetric.get_metric('haversine')
mlb_deduped[['r_lat','r_lon']].to_numpy()
dist.pairwise(mlb_deduped [['r_lat','r_lon']].to_numpy())*6373
# Out:
# array([[   0.        ,  878.8834227 , 2185.72847908, ..., 2149.28965536,
#         2135.89687277, 2950.53420735],
#        [ 878.8834227 ,    0.        , 3036.84667345, ..., 2977.00682989,
#         2948.04633345, 3818.90209704],
#        [2185.72847908, 3036.84667345,    0.        , ...,  230.85706292,
#          353.66269264, 1384.01946314],
#        ...,
#        [2149.28965536, 2977.00682989,  230.85706292, ...,    0.        ,
#          122.8391335 , 1612.87515936],
#        [2135.89687277, 2948.04633345,  353.66269264, ...,  122.8391335 ,
#            0.        , 1735.21707719],
#        [2950.53420735, 3818.90209704, 1384.01946314, ..., 1612.87515936,
#         1735.21707719,    0.        ]])

# %%
dist_matrix=pd.DataFrame(dist.pairwise(mlb_deduped[['r_lat','r_lon']].to_numpy())*6373,  columns=mlb_deduped.LOCATION.unique(), index=mlb_deduped.LOCATION.unique())
dist_matrix
# Out:
#                                          Oracle Park - San Francisco  \
# Oracle Park - San Francisco                                 0.000000
# Oakland Coliseum - Oakland                                878.883423
# Citizens Bank Park - Philadelphia                        2185.728479
# Tropicana Field - St. Petersburg                         2974.683335
# Rogers Centre - Toronto                                  2833.151402
# Target Field - Minneapolis                               1774.723028
# Comerica Park - Detroit                                  2530.925830
# Angel Stadium - Anaheim                                   668.041149
# T-Mobile Park - Seattle                                  1361.345578
# Truist Park - Atlanta                                    2539.927506
# Progressive Field - Cleveland                            2643.353204
# Fenway Park - Boston                                     3512.045520
# Kauffman Stadium - Kansas City                           1559.741278
# Yankee Stadium - Bronx                                   3296.456237
# Globe Life Field - Arlington                             1491.287288
# Rogers Centre - Toronto                            1169.978225  ...
# Target Field - Minneapolis                         1445.274447  ...
# Comerica Park - Detroit                             947.832149  ...
# Angel Stadium - Anaheim                            3073.057981  ...
# T-Mobile Park - Seattle                            3491.025835  ...
# Truist Park - Atlanta                                 0.000000  ...
# Progressive Field - Cleveland                       880.552598  ...
# Fenway Park - Boston                               1498.048608  ...
# Kauffman Stadium - Kansas City                     1062.763631  ...
# Yankee Stadium - Bronx                             1208.488924  ...
# Globe Life Field - Arlington                       1178.549015  ...
# Minute Maid Park - Houston                         1126.098402  ...
# Guaranteed Rate Field - Chicago                     925.619223  ...
# Nationals Park - Washington                         867.443357  ...
# Oriole Park at Camden Yards - Baltimore             921.794841  ...
# Dodger Stadium - Los Angeles                       3100.569357  ...
# Petco Park - San Diego                             3115.410319  ...
# Sahlen Field - Buffalo                             1111.859560  ...
# Coors Field - Denver                               1935.231132  ...
# Chase Field - Phoenix                              2547.663330  ...
# loanDepot park - Miami                              990.782514  ...
# Citi Field - Flushing                              1209.210195  ...
# Busch Stadium - St. Louis                           735.011952  ...
# PNC Park - Pittsburgh                               829.281750  ...
# Great American Ball Park - Cincinnati               579.210718  ...
# Wrigley Field - Chicago                             938.693993  ...
# American Family Field - Milwaukee                  1060.883706  ...
# TD Ballpark - Dunedin                               674.466626  ...
#
#                                          Coors Field - Denver  \
# Oracle Park - San Francisco                        673.086943
# Oakland Coliseum - Oakland                        1517.895173
# Citizens Bank Park - Philadelphia                 1520.353985
# Tropicana Field - St. Petersburg                  2447.923749
# Rogers Centre - Toronto                           2160.854611
# Target Field - Minneapolis                        1123.042887
# Comerica Park - Detroit                           1857.878182
# Angel Stadium - Anaheim                           1323.677915
# T-Mobile Park - Seattle                           1639.149157
# Truist Park - Atlanta                             1935.231132
# Progressive Field - Cleveland                     1971.239266
# Fenway Park - Boston                              2838.961902
# Kauffman Stadium - Kansas City                     906.489971
# Yankee Stadium - Bronx                            2624.705986
# Globe Life Field - Arlington                      1052.953697
# Minute Maid Park - Houston                        1416.807030
# Guaranteed Rate Field - Chicago                   1477.377453
# Nationals Park - Washington                       2400.636296
# Oriole Park at Camden Yards - Baltimore           2424.799073
# Dodger Stadium - Los Angeles                      1334.819215
# Petco Park - San Diego                            1307.576528
# Sahlen Field - Buffalo                            2200.481862
# Coors Field - Denver                                 0.000000
# Chase Field - Phoenix                              943.538363
# loanDepot park - Miami                            2775.186459
# Citi Field - Flushing                             2632.500150
# Busch Stadium - St. Louis                         1280.760834
# PNC Park - Pittsburgh                             2120.322100
# Great American Ball Park - Cincinnati             1757.802274
# Wrigley Field - Chicago                           1476.389975
# American Family Field - Milwaukee                 1463.526418
# TD Ballpark - Dunedin                             2421.524446
#
#                                          Chase Field - Phoenix  \
# Oracle Park - San Francisco                         482.564155
# Oakland Coliseum - Oakland                         1043.889188
# Citizens Bank Park - Philadelphia                  2325.674489
# Tropicana Field - St. Petersburg                   2875.481988
# Rogers Centre - Toronto                            3036.324186
# Target Field - Minneapolis                         2057.272443
# Comerica Park - Detroit                            2716.045387
